# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Read Iris dataset
df = pd.read_csv("iris.csv")

# Rename columns
df.columns = ['x1', 'x2', 'x3', 'x4', 'y']

# Keep only first two features
df = df.drop(['x3', 'x4'], axis=1)

print(df.head(10))

# Create K-Means model
kmeans = KMeans(n_clusters=3, random_state=0)

# Input features
X = df[['x1', 'x2']].values

# Train model
kmeans.fit(X)

# Predict clusters
df['pred'] = kmeans.predict(X)

print("\nClustered Data:")
print(df.head(10))

# Plot clusters
plt.scatter(df['x1'], df['x2'], c=df['pred'])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('k-Means Clustering - Iris Dataset')
plt.show()
# Out:
#     x1   x2            y
# 0  5.1  3.5  Iris-setosa
# 1  4.9  3.0  Iris-setosa
# 2  4.7  3.2  Iris-setosa
# 3  4.6  3.1  Iris-setosa
# 4  5.0  3.6  Iris-setosa
# 5  5.4  3.9  Iris-setosa
# 6  4.6  3.4  Iris-setosa
# 7  5.0  3.4  Iris-setosa
# 8  4.4  2.9  Iris-setosa
# 9  4.9  3.1  Iris-setosa
#
# Clustered Data:
#     x1   x2            y  pred
# 0  5.1  3.5  Iris-setosa     2
# 1  4.9  3.0  Iris-setosa     2
# 2  4.7  3.2  Iris-setosa     2
# 3  4.6  3.1  Iris-setosa     2
# 4  5.0  3.6  Iris-setosa     2
# 5  5.4  3.9  Iris-setosa     2
# 6  4.6  3.4  Iris-setosa     2
# 7  5.0  3.4  Iris-setosa     2
# 8  4.4  2.9  Iris-setosa     2
# 9  4.9  3.1  Iris-setosa     2
